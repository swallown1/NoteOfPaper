# %% [markdown]
# # DeepFM
# 细节部分：
#
#    对于嵌入部分，每一特征代表一个feild  这里的数据每个特征是一个值
#
#    对于离散值和连续值进行处理，得到一个 ∑n_i * featrue_size_i
#
#    通过对每个特征的词嵌入，将特征转移到特定维度维度，对于每个filed
#    嵌入矩阵的大小是  feature_size_i * embedding
#
#    对于Deep部分：将得到的Embedding，拼接成，输入的大小(n_feild * embedding)
#
#    对于FM部分：这里的Vi,f使用的是之前的Embedding的权重，也就是说K = embedding，这里在做矩阵相乘时候】， 由于是one-hot形式，所以不是直用x的整个向量，而是用 1值得索引乘以嵌入矩阵，这里的嵌入矩阵也就是Embedding部分的矩阵。再通过公式计算二阶特征交叉部分。
#
#    最后一层DNN 是将Deep，FM 部分的输出元素求和,在通过激活得到预测值，在他通过交叉熵计算损失。
#
# #### 参考文章
# [deepFM in pytorch](https://blog.csdn.net/w55100/article/details/90295932)
#
# [DeepFM全方面解析（附pytorch源码）](https://zhuanlan.zhihu.com/p/84526966)
#
# [原文翻译](https://zhuanlan.zhihu.com/p/57873613)

# %%
import numpy as np

import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

from data.dataset import CriteoDataset

# %% [markdown]
# ### 加载数据

# %%
train_data = CriteoDataset('./data',train=True)

# %%
train_data

# %%
# 900000 items for training, 10000 items for valid, of all 1000000 items
Num_train = 800
# 产生batch 的数据   随机产生
loader_train = DataLoader(train_data,batch_size=50,
                    sampler=sampler.SubsetRandomSampler(range(Num_train)))

# %%
feature_sizes = np.loadtxt('./data/feature_sizes.txt', delimiter=',')
feature_sizes = [int(x) for x in feature_sizes]
len(feature_sizes)
# Out:
# 39

# %%
loader_train.dataset

# %% [markdown]
# ### DeepModel

# %%
import torch.nn as nn
import torch.nn.functional as F
from time import time

# %%
class DeepFM(nn.Module):
    def __init__(self, feature_sizes, embedding_size=4,
                 hidden_dims=[32, 32], num_classes=10, dropout=[0.5, 0.5], 
                 use_cuda=False, verbose=False):
        super().__init__()
        self.field_size = len(feature_sizes)
        self.feature_sizes = feature_sizes
        self.embedding_size = embedding_size
        self.hidden_dims = hidden_dims
        self.num_classes = num_classes
        self.dtype = torch.float
        
        self.device = torch.device('cpu')
        
        """
        init fm part
        """
#       (0): Linear(in_features=1, out_features=4, bias=True)
#         连续值  使用全连接神经网络
        fm_first_order_Linears = nn.ModuleList(
                [nn.Linear(feature_size, self.embedding_size) for feature_size in self.feature_sizes[:13]])

#       (0): Embedding(1, 4) (1): Embedding(1, 4)
#          离散值  使用Embedding
        fm_first_order_embeddings = nn.ModuleList(
                [nn.Embedding(feature_size, self.embedding_size) for feature_size in self.feature_sizes[13:40]])
        
#         (12): Linear(in_features=1, out_features=4, bias=True)
#         (13): Embedding(1, 4)
        self.fm_first_order_models = fm_first_order_Linears.extend(fm_first_order_embeddings)    
        
#         二阶
        fm_second_order_Linears = nn.ModuleList(
                [nn.Linear(feature_size, self.embedding_size) for feature_size in self.feature_sizes[:13]])
        fm_second_order_embeddings = nn.ModuleList(
                [nn.Embedding(feature_size, self.embedding_size) for feature_size in self.feature_sizes[13:40]])
        self.fm_second_order_models = fm_second_order_Linears.extend(fm_second_order_embeddings)
        
        
        """
            init deep part
            这部分是整个模型这最后的DNN部分
        """
        all_dims = [self.field_size * self.embedding_size] + \
            self.hidden_dims + [self.num_classes]
        
        for i in range(1, len(hidden_dims) + 1):
            setattr(self, 'linear_'+str(i),
                    nn.Linear(all_dims[i-1], all_dims[i]))
            # nn.init.kaiming_normal_(self.fc1.weight)
            setattr(self, 'batchNorm_' + str(i),
                    nn.BatchNorm1d(all_dims[i]))
            setattr(self, 'dropout_'+str(i),
                    nn.Dropout(dropout[i-1]))


    def forward(self, Xi, Xv):
        """
        Inputs:
        - Xi: 索引值 (N, field_size, 1)
        - Xv: 具体的值 (N, field_size, 1)
        """
        """
            fm part
        """
        emb = self.fm_first_order_models[20]
        for num in Xi[:, 20, :][0]:
            if num > self.feature_sizes[20]:
                print("index out")
#         将所有特征进行emdedding 采用索引去嵌入矩阵找Embedding 减少计算量
#         这部分也是FM1 部分  即 ∑vi,f xn
        fm_first_order_emb_arr = []
        for i, emb in enumerate(self.fm_first_order_models):
#             连续值
            if i <=12:
                Xi_tem = Xi[:, i, :].to(device=self.device, dtype=torch.float)
                fm_first_order_emb_arr.append((torch.sum(emb(Xi_tem).unsqueeze(1), 1).t() * Xv[:, i]).t())
            else:
                Xi_tem = Xi[:, i, :].to(device=self.device, dtype=torch.long)
                fm_first_order_emb_arr.append((torch.sum(emb(Xi_tem), 1).t() * Xv[:, i]).t())
        
        fm_first_order = torch.cat(fm_first_order_emb_arr, 1)
        
#         这部分也是FM2 部分  即 ∑vi,f xn
        fm_second_order_emb_arr = []
        for i, emb in enumerate(self.fm_second_order_models):
            if i <=12:
                Xi_tem = Xi[:, i, :].to(device=self.device, dtype=torch.float)
                fm_second_order_emb_arr.append((torch.sum(emb(Xi_tem).unsqueeze(1), 1).t() * Xv[:, i]).t())
            else:
                Xi_tem = Xi[:, i, :].to(device=self.device, dtype=torch.long)
                fm_second_order_emb_arr.append((torch.sum(emb(Xi_tem), 1).t() * Xv[:, i]).t())
        
        fm_sum_second_order_emb = sum(fm_second_order_emb_arr)
        fm_sum_second_order_emb_square = fm_sum_second_order_emb * \
            fm_sum_second_order_emb  # (x+y)^2
        fm_second_order_emb_square = [
            item*item for item in fm_second_order_emb_arr]
        fm_second_order_emb_square_sum = sum(
            fm_second_order_emb_square)  # x^2+y^2
        fm_second_order = (fm_sum_second_order_emb_square -
                           fm_second_order_emb_square_sum) * 0.5
        
        
#             shape = n_fild * embedding_size
        deep_emb = torch.cat(fm_second_order_emb_arr, 1)
        deep_out = deep_emb
        for i in range(1, len(self.hidden_dims) + 1):
            deep_out = getattr(self, 'linear_' + str(i))(deep_out)
            deep_out = getattr(self, 'batchNorm_' + str(i))(deep_out)
            deep_out = getattr(self, 'dropout_' + str(i))(deep_out)
        
#         sum
        bias = torch.nn.Parameter(torch.randn(Xi.size(0)))
        total_sum = torch.sum(fm_first_order, 1) + \
                    torch.sum(fm_second_order, 1) + \
                    torch.sum(deep_out, 1) + bias
        return total_sum

    def fit(self, loader_train, loader_val, optimizer, epochs=1, verbose=False, print_every=5):
       
        model = self.train().to(device=self.device)
        criterion = F.binary_cross_entropy_with_logits

        for epoch in range(epochs):
            for t, (xi, xv, y) in enumerate(loader_train):
                xi = xi.to(device=self.device, dtype=self.dtype)
                xv = xv.to(device=self.device, dtype=torch.float)
                y = y.to(device=self.device, dtype=self.dtype)
                
                total = model(xi, xv)
#                print(total.shape)
#                print(y.shape)
                loss = criterion(total, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if verbose and t % print_every == 0:
                    print('Epoch %d Iteration %d, loss = %.4f' % (epoch, t, loss.item()))
                    self.check_accuracy(loader_val, model)
                    print()
    
    def check_accuracy(self, loader, model):
        if loader.dataset.train:
            print('Checking accuracy on validation set')
        else:
            print('Checking accuracy on test set')   
        num_correct = 0
        num_samples = 0
        model.eval()  # set model to evaluation mode
        with torch.no_grad():
            for xi, xv, y in loader:
                xi = xi.to(device=self.device, dtype=self.dtype)  # move to device, e.g. GPU
                xv = xv.to(device=self.device, dtype=self.dtype)
                y = y.to(device=self.device, dtype=self.dtype)
                total = model(xi, xv)
                preds = (F.sigmoid(total) > 0.5).to(dtype=self.dtype)
#                print(preds.dtype)
#                print(y.dtype)
#                print(preds.eq(y).cpu().sum())
                num_correct += (preds == y).sum()
                num_samples += preds.size(0)
#                print("successful")
            acc = float(num_correct) / num_samples
            print('Got %d / %d correct (%.2f%%)' % (num_correct, num_samples, 100 * acc))

# %%
model = DeepFM(feature_sizes, use_cuda=False)

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=0.0)

# %%
val_data = CriteoDataset('./data', train=True)
loader_val = DataLoader(val_data, batch_size=50,
                        sampler=sampler.SubsetRandomSampler(range(Num_train, 899)))

# %%
model.fit(loader_train, loader_val, optimizer, epochs=100, verbose=True)
# Out:
# Epoch 0 Iteration 0, loss = 867554.1875
# Checking accuracy on validation set
# Got 36 / 99 correct (36.36%)
# G:\Anaconda\lib\site-packages\torch\nn\functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 0 Iteration 5, loss = 2145652.5000
# Checking accuracy on validation set
# Got 36 / 99 correct (36.36%)
#
# Epoch 0 Iteration 10, loss = 414614.0000
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 0 Iteration 15, loss = 364650.5938
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 1 Iteration 0, loss = 362912.5625
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 1 Iteration 5, loss = 270534.9062
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 1 Iteration 10, loss = 1284424.0000
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 1 Iteration 15, loss = 836077.8125
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 2 Iteration 0, loss = 436198.8750
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 2 Iteration 5, loss = 953946.2500
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 2 Iteration 10, loss = 501731.5938
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 2 Iteration 15, loss = 460512.0312
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 3 Iteration 0, loss = 309154.0938
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 3 Iteration 5, loss = 545977.8125
# Checking accuracy on validation set
# Got 37 / 99 correct (37.37%)
#
# Epoch 3 Iteration 10, loss = 611105.6250
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 3 Iteration 15, loss = 643487.3750
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 4 Iteration 0, loss = 804096.9375
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 4 Iteration 5, loss = 1982569.6250
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 4 Iteration 10, loss = 728905.4375
# Checking accuracy on validation set
# Got 38 / 99 correct (38.38%)
#
# Epoch 4 Iteration 15, loss = 809591.5000
# Checking accuracy on validation set
# Got 39 / 99 correct (39.39%)
#
# Epoch 5 Iteration 0, loss = 620601.4375
# Checking accuracy on validation set
# Got 39 / 99 correct (39.39%)
#
# Epoch
# Checking accuracy on validation set
# Got 39 / 99 correct (39.39%)
#
# Epoch 20 Iteration 5, loss = 325328.9375
# Checking accuracy on validation set
# Got 39 / 99 correct (39.39%)
#
# Epoch 20 Iteration 10, loss = 288436.9688
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 20 Iteration 15, loss = 449572.5312
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 21 Iteration 0, loss = 401086.4688
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 21 Iteration 5, loss = 766924.5625
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 21 Iteration 10, loss = 206574.5156
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 21 Iteration 15, loss = 263214.4062
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 22 Iteration 0, loss = 492200.0938
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 22 Iteration 5, loss = 1271138.7500
# Checking accuracy on validation set
# Got 40 / 99 correct (40.40%)
#
# Epoch 22 Iteration 10, loss = 643972.0625
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 22 Iteration 15, loss = 622537.7500
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 23 Iteration 0, loss = 288333.7500
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 23 Iteration 5, loss = 458503.8750
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 23 Iteration 10, loss = 293702.3750
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 23 Iteration 15, loss = 236043.7656
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 24 Iteration 0, loss = 1024488.8125
# Checking accuracy on validation set
# Got 41 / 99 correct (41.41%)
#
# Epoch 24 Iteration 5, loss = 451776.2812
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 24 Iteration 10, loss = 1664751.6250
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 24 Iteration 15, loss = 638669.7500
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 25 Iteration 0, loss = 829846.3750
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 25 Iteration 5, loss = 1651007.2500
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 25 Iteration 10, loss = 243391.6250
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 25 Iteration 15, loss = 378305.5938
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 26 Iteration 0, loss = 230794.2969
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 26 Iteration 5, loss = 1637827.5000
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 26 Iteration 10, loss = 715538.0000
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 26 Iteration 15, loss = 385197.4375
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 27 Iteration 0, loss = 173484.8750
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 27 Iteration 5, loss = 313217.3125
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 27 Iteration 10, loss = 610354.9375
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 27 Iteration 15, loss = 483249.8750
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 28 Iteration 0, loss = 257278.1562
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 28 Iteration 5, loss = 940448.1875
# Checking accuracy on validation set
# Got 42 / 99 correct (42.42%)
#
# Epoch 28 Iteration 10, loss = 1999275.2500
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch 28 Iteration 15, loss = 413461.9688
# Checking accuracy on validation set
# Got 43 / 99 correct (43.43%)
#
# Epoch
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 61 Iteration 5, loss = 197197.3594
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 61 Iteration 10, loss = 251388.9531
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 61 Iteration 15, loss = 488551.7500
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 62 Iteration 0, loss = 1065839.6250
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 62 Iteration 5, loss = 222958.3125
# Checking accuracy on validation set
# Got 51 / 99 correct (51.52%)
#
# Epoch 62 Iteration 10, loss = 332829.2500
# Checking accuracy on validation set
# Got 52 / 99 correct (52.53%)
#
# Epoch 62 Iteration 15, loss = 179949.3438
# Checking accuracy on validation set
# Got 52 / 99 correct (52.53%)
#
# Epoch 63 Iteration 0, loss = 88484.1719
# Checking accuracy on validation set
# Got 52 / 99 correct (52.53%)
#
# Epoch 63 Iteration 5, loss = 513260.1562
# Checking accuracy on validation set
# Got 52 / 99 correct (52.53%)
#
# Epoch 63 Iteration 10, loss = 66981.0391
# Checking accuracy on validation set
# Got 52 / 99 correct (52.53%)
#
# Epoch 63 Iteration 15, loss = 577418.0625
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 64 Iteration 0, loss = 155173.5938
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 64 Iteration 5, loss = 426470.5625
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 64 Iteration 10, loss = 108542.4609
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 64 Iteration 15, loss = 75142.8438
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 65 Iteration 0, loss = 108251.5000
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 65 Iteration 5, loss = 412717.4375
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 65 Iteration 10, loss = 212689.2344
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 65 Iteration 15, loss = 139701.2812
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 66 Iteration 0, loss = 531661.5625
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 66 Iteration 5, loss = 113516.1016
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 66 Iteration 10, loss = 110303.0938
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 66 Iteration 15, loss = 492455.3750
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 67 Iteration 0, loss = 208755.2656
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 67 Iteration 5, loss = 93298.7578
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 67 Iteration 10, loss = 144107.3594
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 67 Iteration 15, loss = 241266.9062
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 68 Iteration 0, loss = 1018514.5000
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 68 Iteration 5, loss = 59661.6641
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 68 Iteration 10, loss = 294067.3125
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 68 Iteration 15, loss = 327324.2812
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 69 Iteration 0, loss = 405858.3750
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 69 Iteration 5, loss = 343510.1562
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 69 Iteration 10, loss = 153802.3281
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 69 Iteration 15, loss = 140588.9844
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 70 Iteration 0, loss = 66210.2422
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 70 Iteration 5, loss = 390140.5938
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 70 Iteration 10, loss = 934957.6250
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 70 Iteration 15, loss = 175570.8125
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 71 Iteration 0, loss = 568862.2500
# Checking accuracy on validation set
# Got 53 / 99 correct (53.54%)
#
# Epoch 71 Iteration 5, loss = 288993.0938
# Checking accuracy on validation set
# Got 54 / 99 correct (54.55%)
#
# Epoch 71 Iteration 10, loss = 19082.4395
# Checking accuracy on validation set
# Got 54 / 99 correct (54.55%)
#
# Epoch 71 Iteration 15, loss = 186133.7031
# Checking accuracy on validation set
# Got 55 / 99 correct (55.56%)
#
# Epoch 72 Iteration 0, loss = 52833.1719
# Checking accuracy on validation set
# Got 55 / 99 correct (55.56%)
#
# Epoch 72 Iteration 5, loss = 531114.5000
# Checking accuracy on validation set
# Got 55 / 99 correct (55.56%)
#
# Epoch 72 Iteration 10, loss = 62093.2969
# Checking accuracy on validation set
# Got 55 / 99 correct (55.56%)
#
# Epoch 72 Iteration 15, loss = 152560.8281
# Checking accuracy on validation set
# Got 56 / 99 correct (56.57%)
#
# Epoch 73 Iteration 0, loss = 292169.4688
# Checking accuracy on validation set
# Got 56 / 99 correct (56.57%)
#
# Epoch 73 Iteration 5, loss = 222485.2031
# Checking accuracy on validation set
# Got 56 / 99 correct (56.57%)
#
# Epoch 73 Iteration 10, loss = 70478.1719
# Checking accuracy on validation set
# Got 56 / 99 correct (56.57%)
#
# Epoch 73 Iteration 15, loss = 227349.3750
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 74 Iteration 0, loss = 61629.1914
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 74 Iteration 5, loss = 175456.2188
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 74 Iteration 10, loss = 137773.2656
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 74 Iteration 15, loss = 171654.9531
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 75 Iteration 0, loss = 669458.5000
# Checking accuracy on validation set
# Got 57 / 99 correct (57.58%)
#
# Epoch 75 Iteration 5, loss = 398322.7188
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 75 Iteration 10, loss = 274125.7500
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 75 Iteration 15, loss = 152218.2656
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 76 Iteration 0, loss = 101229.1484
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 76 Iteration 5, loss = 54604.0664
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 76 Iteration 10, loss = 101191.7969
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
# Epoch 76 Iteration 15, loss = 418174.0000
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 77 Iteration 0, loss = 63881.1719
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 77 Iteration 5, loss = 240106.2188
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 77 Iteration 10, loss = 97255.1406
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 77 Iteration 15, loss = 262856.9062
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 78 Iteration 0, loss = 274786.2812
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 78 Iteration 5, loss = 932487.6250
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 78 Iteration 10, loss = 60115.8281
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 78 Iteration 15, loss = 190426.2812
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 79 Iteration 0, loss = 108155.7109
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 79 Iteration 5, loss = 144671.8281
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 79 Iteration 10, loss = 477908.5938
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 79 Iteration 15, loss = 267123.4688
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 80 Iteration 0, loss = 16246.0566
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 80 Iteration 5, loss = 190147.9062
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 80 Iteration 10, loss = 245036.7188
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 80 Iteration 15, loss = 302583.1875
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 81 Iteration 0, loss = 55818.1289
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 81 Iteration 5, loss = 493829.4688
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 81 Iteration 10, loss = 147164.8750
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 81 Iteration 15, loss = 269352.3125
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 82 Iteration 0, loss = 78321.0469
# Checking accuracy on validation set
# Got 58 / 99 correct (58.59%)
#
# Epoch 82 Iteration 5, loss = 169514.7812
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 82 Iteration 10, loss = 1038234.0625
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 82 Iteration 15, loss = 302369.7812
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 83 Iteration 0, loss = 266861.2812
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 83 Iteration 5, loss = 73519.7578
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 83 Iteration 10, loss = 231765.5469
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 83 Iteration 15, loss = 173871.1562
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 84 Iteration 0, loss = 119880.7734
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 84 Iteration 5, loss = 144499.0938
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 84 Iteration 10, loss = 109837.9609
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 84 Iteration 15, loss = 70796.7031
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 85 Iteration 0, loss = 227574.3125
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 85 Iteration 5, loss = 67669.9062
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 85 Iteration 10, loss = 84045.7734
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 85 Iteration 15, loss = 152586.5156
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 86 Iteration 0, loss = 108009.0781
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 86 Iteration 5, loss = 93174.5625
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 86 Iteration 10, loss = 166884.2344
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 86 Iteration 15, loss = 171929.0781
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 87 Iteration 0, loss = 950872.5000
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 87 Iteration 5, loss = 195509.4062
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 87 Iteration 10, loss = 242520.4844
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 87 Iteration 15, loss = 408697.1250
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 88 Iteration 0, loss = 776567.4375
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 88 Iteration 5, loss = 57997.5742
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 88 Iteration 10, loss = 79287.2109
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 88 Iteration 15, loss = 153637.7031
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 89 Iteration 0, loss = 479877.4062
# Checking accuracy on validation set
# Got 59 / 99 correct (59.60%)
#
# Epoch 89 Iteration 5, loss = 127677.4062
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 89 Iteration 10, loss = 54995.0703
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 89 Iteration 15, loss = 178425.9062
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 90 Iteration 0, loss = 327585.9062
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 90 Iteration 5, loss = 143232.9375
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 90 Iteration 10, loss = 22173.0527
# Checking accuracy on validation set
# Got 60 / 99 correct (60.61%)
#
# Epoch 90 Iteration 15, loss = 184673.9375
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 91 Iteration 0, loss = 746013.4375
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 91 Iteration 5, loss = 75345.7031
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 91 Iteration 10, loss = 226040.0000
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 91 Iteration 15, loss = 264907.3750
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 92 Iteration 0, loss = 77205.2188
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 92 Iteration 5, loss = 124495.7500
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 92 Iteration 10, loss = 455564.1250
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 92 Iteration 15, loss = 49338.9219
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 93 Iteration 0, loss = 152626.4219
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 93 Iteration 5, loss = 234748.5781
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 93 Iteration 10, loss = 85081.8281
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 93 Iteration 15, loss = 799765.0625
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 94 Iteration 0, loss = 244257.7969
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 94 Iteration 5, loss = 63672.6406
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 94 Iteration 10, loss = 129602.0703
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 94 Iteration 15, loss = 65690.8516
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 95 Iteration 0, loss = 32434.2246
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 95 Iteration 5, loss = 174657.6406
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 95 Iteration 10, loss = 51587.3359
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 95 Iteration 15, loss = 338065.8750
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 96 Iteration 0, loss = 511795.6875
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
# Epoch 96 Iteration 5, loss = 120553.8984
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 96 Iteration 10, loss = 268369.9688
# Checking accuracy on validation set
# Got 61 / 99 correct (61.62%)
#
# Epoch 96 Iteration 15, loss = 86923.5938
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 97 Iteration 0, loss = 124562.5703
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 97 Iteration 5, loss = 87609.6562
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 97 Iteration 10, loss = 40275.4844
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 97 Iteration 15, loss = 167317.3906
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 98 Iteration 0, loss = 143867.7969
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 98 Iteration 5, loss = 84273.2734
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 98 Iteration 10, loss = 28647.1367
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 98 Iteration 15, loss = 134699.5469
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 99 Iteration 0, loss = 48403.4258
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 99 Iteration 5, loss = 89525.1797
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 99 Iteration 10, loss = 174026.7656
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
#
# Epoch 99 Iteration 15, loss = 28203.8477
# Checking accuracy on validation set
# Got 62 / 99 correct (62.63%)
